# %%
# Dependencies
import pandas as pd

# %%
# load CSV
file = "Resources/2016-FCC-New-Coders-Survey-Data.csv"

# %%
# Read with pandas--low_memory required to suppress errors about mixed data types
file_df = pd.read_csv(file, encoding="ISO-8859-1")
file_df.head(5)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (21,57) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# ...

# %%
# Take only columns 0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111
coders_df = file_df.iloc[:,[0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]]
coders_df
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0      28.0               0.0             NaN                   NaN
# 1      22.0               0.0             NaN                   NaN
# 2      19.0               0.0             NaN                   NaN
# 3      26.0               0.0             NaN                   NaN
# 4      20.0               0.0             NaN                   NaN
# ...     ...               ...             ...                   ...
# 15615  39.0               0.0             NaN                   NaN
# 15616  27.0               0.0             NaN                   NaN
# 15617  37.0               0.0             NaN                   NaN
# 15618  26.0               0.0             NaN                   NaN
# 15619  22.0               0.0             NaN                   NaN
#
#        BootcampLoanYesNo BootcampName  BootcampPostSalary  BootcampRecommend  \
# ...

# %%
# Change reading 0 and 1 to No and Yes, respectively
coders_df = coders_df.replace({0:"No"})
coders_df = coders_df.replace({1:"Yes"})
coders_df
# Out:
#         Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 0      28.0               No            NaN                  NaN
# 1      22.0               No            NaN                  NaN
# 2      19.0               No            NaN                  NaN
# 3      26.0               No            NaN                  NaN
# 4      20.0               No            NaN                  NaN
# ...     ...              ...            ...                  ...
# 15615  39.0               No            NaN                  NaN
# 15616  27.0               No            NaN                  NaN
# 15617  37.0               No            NaN                  NaN
# 15618  26.0               No            NaN                  NaN
# 15619  22.0               No            NaN                  NaN
#
#       BootcampLoanYesNo BootcampName  BootcampPostSalary BootcampRecommend  \
# 0                   NaN          NaN                 NaN               NaN
# ...

# %%
# Extract rows for only those who attended a bootcamp
attended_df = coders_df.loc[coders_df["AttendedBootcamp"] == "Yes"]
attended_df
# Out:
#         Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 93     32.0              Yes            Yes                   No
# 97     26.0              Yes            Yes                  Yes
# 130    41.0              Yes            Yes                  Yes
# 159    26.0              Yes            Yes                   No
# 188    24.0              Yes             No                  NaN
# ...     ...              ...            ...                  ...
# 15539  39.0              Yes            Yes                  Yes
# 15540  24.0              Yes            Yes                  Yes
# 15541  23.0              Yes            Yes                  Yes
# 15593  29.0              Yes             No                  NaN
# 15600  28.0              Yes            Yes                  Yes
#
#       BootcampLoanYesNo              BootcampName  BootcampPostSalary  \
# 93                   No            Codify Academy                 NaN
# ...

# %%
# Create DataFrame of the different boot camps that had a significant number of attendees
attended_df['BootcampName'].value_counts()
#defining bootcamps_count as equal to the value counts of the 'BootcampName' column
bootcamps_count = attended_df['BootcampName'].value_counts(dropna=True, sort=True)
#setting the value count as the data frame 
bootcampcount_df = pd.DataFrame(bootcamps_count)
bootcamps_df = bootcampcount_df.reset_index()
#change name of the columns
bootcamps_df.columns = ['Bootcamp', 'Attendees']
bootcamps_df
# Out:
#                                           Bootcamp  Attendees
# 0                                 General Assembly         90
# 1                                  Flatiron School         54
# 2                                     Dev Bootcamp         48
# 3                                    The Iron Yard         40
# 4                            Prime Digital Academy         30
# ..                                             ...        ...
# 123  Microsoft Research Data Science Summer School          1
# 124                            Origin Code Academy          1
# 125                                  Claim Academy          1
# 126                                        Code 42          1
# 127                                  Coder Foundry          1
#
# [128 rows x 2 columns]

# %%
# Count how many attendees of each bootcamp would recommend the bootcamp
recommend_df = attended_df.loc[attended_df['BootcampRecommend'] == 'Yes']
rec_bootcamp_count = recommend_df['BootcampName'].value_counts()
rec_count_df = pd.DataFrame(rec_bootcamp_count)
rec_df = rec_count_df.reset_index()
rec_df.columns = ['Bootcamp', 'Recommend']
rec_df
# Out:
#                                      Bootcamp  Recommend
# 0                            General Assembly         70
# 1                             Flatiron School         50
# 2                                Dev Bootcamp         41
# 3                               The Iron Yard         31
# 4                                Hack Reactor         27
# ..                                        ...        ...
# 111                            Base10 Academy          1
# 112  Launch School (formerly Tealeaf Academy)          1
# 113                            Codify Academy          1
# 114                       AngelHack Education          1
# 115                             Coder Foundry          1
#
# [116 rows x 2 columns]

# %%
# Merge the two created data frames on the name of the bootcamp
merged_df = pd.merge(bootcamps_df, rec_df)
merged_df
# Out:
#                                           Bootcamp  Attendees  Recommend
# 0                                 General Assembly         90         70
# 1                                  Flatiron School         54         50
# 2                                     Dev Bootcamp         48         41
# 3                                    The Iron Yard         40         31
# 4                            Prime Digital Academy         30         25
# ..                                             ...        ...        ...
# 111  Microsoft Research Data Science Summer School          1          1
# 112                            Origin Code Academy          1          1
# 113                                  Claim Academy          1          1
# 114                                        Code 42          1          1
# 115                                  Coder Foundry          1          1
#
# [116 rows x 3 columns]

# %%
# Calculate percentage of each bootcamp's students who are recommenders

merged_df['% Recommended']= round((merged_df['Recommend'] / merged_df['Attendees']) * 100, 2)
merged_df
# Out:
#                                           Bootcamp  Attendees  Recommend  \
# 0                                 General Assembly         90         70
# 1                                  Flatiron School         54         50
# 2                                     Dev Bootcamp         48         41
# 3                                    The Iron Yard         40         31
# 4                            Prime Digital Academy         30         25
# ..                                             ...        ...        ...
# 111  Microsoft Research Data Science Summer School          1          1
# 112                            Origin Code Academy          1          1
# 113                                  Claim Academy          1          1
# 114                                        Code 42          1          1
# 115                                  Coder Foundry          1          1
#
#      % Recommended
# 0            77.78
# 1            92.59
# 2            85.42
# ...

# %%
# Export to excel and remove index
merged_df.to_excel("output/BootcampOutputPart2.xlsx", index=False)
